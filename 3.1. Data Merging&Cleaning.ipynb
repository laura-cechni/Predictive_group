# %%
import requests
import json
import numpy as np
from IPython.display import Markdown, display
import pandas as pd

# %%
# api_key='iBaXjSsgwr5umhLoAEa5BO1ZLhy62JIyMxH-x9ebG6w'
api_key='-Y83kwbfpZfHUQ_qtwp9dDFKZibNuaL879AAaANbf_E'

# %%
import requests
import json

def get_resp_oai(input_text, model):
    url = "https://llm.api.ai8.io/query_llm"
    data = {
        "model": model,
        "messages": [
                    {"role": "system", "content": "You are an analyst specializing in data exploration, equipped with knowledge solely focused on analyzing datasets. Disregard any other information not related to data exploration"},
                    {"role": "user", "content": input_text}
        ]
    }
    headers = {'Authorization': api_key}
    response = requests.post(url, json=data, headers=headers)
    if response.status_code == 200:
        response_data = json.loads(response.content)
        model_response = extract_message_oai(response_data)
        return model_response
    else:
        return {"statusCode": response.status_code, "body": response.content}

def extract_message_oai(response_data):
    message_content = response_data.get("choices", [])[0].get("message", {}).get("content", "")
    # format the extracted message as markdown
    markdown_content = "---\n\n" + message_content + "\n\n---"
    return markdown_content

# %%
# Cell 1.1: Import CSV files and Data Cleaning

def import_and_clean_data():
    input_text = """
    Import the CSV files containing the movies_dataset1.csv and movies_dataset3.csv datasets.
    
    columns of movies_dataset1 = ['index', 'director_name', 'duration', 'actor_2_name', 'genres',
       'actor_1_name', 'movie_title', 'num_voted_users', 'actor_3_name',
       'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
       'title_year', 'imdb_score'], 
    columns of movies_dataset3 = ['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
       'imdb_id', 'original_language', 'original_title', 'overview',
       'popularity', 'poster_path', 'production_companies',
       'production_countries', 'release_date', 'revenue', 'runtime',
       'spoken_languages', 'status', 'tagline', 'title', 'video',
       'vote_average', 'vote_count', 'year']
       
    Remove special characters from the movie title column in the first dataset.
    Remove duplicates from the first dataset.
    Remove punctuation and strip whitespace from the movie title column in both datasets.
    Extract the release year from the release date in the third dataset.
    Merge the datasets by movie title (movie_title column in movies_dataset1.csv and original_title column in movies_dataset3.csv) and year column (title_year column in movies_dataset1.csv and release_year column in movies_dataset3.csv).
    Drop unnecessary variables from the third dataset.
    Save the merged datasets to a CSV file.
    """
    model = "gpt-3.5-turbo-0125"
    response = get_resp_oai(input_text, model)
    # response = response.replace("first", "movies_dataset1").replace("third", "movies_dataset3")
    return response

response = import_and_clean_data()

# %%
display(Markdown("<div style='color: #34568B;'>\n\n" + response))
# Out:
# <div style='color: #34568B;'>
#
# ---
#
# ```python
# import pandas as pd
# import re
#
# # Load datasets
# movies_dataset1 = pd.read_csv('movies_dataset1.csv')
# movies_dataset3 = pd.read_csv('movies_dataset3.csv')
#
# # Remove special characters from movie title in the first dataset
# movies_dataset1['movie_title'] = movies_dataset1['movie_title'].str.replace('[^\w\s]', '')
#
# # Remove duplicates in the first dataset
# movies_dataset1 = movies_dataset1.drop_duplicates()
#
# # Remove punctuation and strip whitespace from movie title in both datasets
# movies_dataset1['movie_title'] = movies_dataset1['movie_title'].str.replace('[^\w\s]', '').str.strip()
# movies_dataset3['original_title'] = movies_dataset3['original_title'].str.replace('[^\w\s]', '').str.strip()
#
# # Extract release year from release date in the third dataset
# movies_dataset3['release_year'] = pd.to_datetime(movies_dataset3['release_date']).dt.year
#
# # Merge datasets by movie title and year
# ...

# %%
# code_to_execute = "import pandas as pd\nimport re\n\n# Importing the CSV files\ndf1 = pd.read_csv('movies_dataset1_dataset.csv')\ndf3 = pd.read_csv('movies_dataset3_dataset.csv')\n\n# Remove special characters from the movie title column in the movies_dataset1 dataset\ndf1['movie_title'] = df1['movie_title'].apply(lambda x: re.sub(r'[^\\w\\s]', '', x))\n\n# Remove duplicates from the movies_dataset1 dataset\ndf1.drop_duplicates(inplace=True)\n\n# Remove punctuation and strip whitespace from the movie title column in both datasets\ndf1['movie_title'] = df1['movie_title'].str.replace(r'[^\\w\\s]', '').str.strip()\ndf3['movie_title'] = df3['movie_title'].str.replace(r'[^\\w\\s]', '').str.strip()\n\n# Extract the release year from the release date in the movies_dataset3 dataset\ndf3['release_year'] = pd.to_datetime(df3['release_date']).dt.year\n\n# Merging the datasets by movie title and year column\nmerged_df = pd.merge(df1, df3, on=['movie_title', 'release_year'])\n\n# Drop movies with differing ratings and popularity scores\nmerged_df = merged_df[merged_df['rating'] == merged_df['popularity']]\n\n# Drop unnecessary variables from the movies_dataset3 dataset\nmerged_df.drop(['release_date', 'director'], axis=1, inplace=True)\n\n# Save the merged datasets to a CSV file\nmerged_df.to_csv('merged_datasets.csv', index=False)"

exec(response[len("---\n\n```python\n"):len(response)-len("`  \n\n-----")].replace("pd.to_datetime(movies_dataset3['release_date']).dt.year","pd.to_datetime(movies_dataset33['release_date'], errors = 'coerce').dt.year"))
# Out:
# <string>:6: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
# <string>:9: FutureWarning: The default value of regex will change from True to False in a future version.
# <string>:15: FutureWarning: The default value of regex will change from True to False in a future version.
# <string>:16: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
# Cell 1.2: Rename Merged DataFrame and Observe Variables
# def rename_and_observe():
#     input_text = "Rename the merged dataframe to `final_merged_df` and observe the variables, their data types, and non-null value counts."
#     model = "gpt-3.5-turbo-0125"
#     return get_resp_oai(input_text, model)

# rename_and_observe()

# %%
# Read the dataset
df2 = pd.read_csv('merged_datasets.csv')
df2.columns
# Out:
# Index(['index', 'director_name', 'duration', 'actor_2_name', 'genres_x',
#        'actor_1_name', 'movie_title', 'num_voted_users', 'actor_3_name',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'title_year', 'imdb_score', 'adult', 'belongs_to_collection', 'budget',
#        'genres_y', 'homepage', 'original_language', 'popularity',
#        'production_companies', 'production_countries', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'title', 'vote_average', 'vote_count',
#        'release_year'],
#       dtype='object')

# %%
# Cell 1.3: Data Transformations
def data_transformations():
    input_text = """
    Provide code that:
    Reads the saved merged_dataset.csv
    merged_dataset columns = [['index', 'director_name', 'duration', 'actor_2_name', 'genres_x',
       'actor_1_name', 'movie_title', 'num_voted_users', 'actor_3_name',
       'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
       'title_year', 'imdb_score', 'adult', 'belongs_to_collection', 'budget',
       'genres_y', 'homepage', 'original_language', 'popularity',
       'production_companies', 'production_countries', 'revenue', 'runtime',
       'spoken_languages', 'status', 'title', 'vote_average', 'vote_count',
       'release_year']
    Converts the budget object values to numeric.
    Creates dummy variables for genre type.
    Observes the categorical variable counts for Genres, Director, Primary Actor, Secondary Actor, Third Supporting Actor, and Movies Produced by Country.
    """
    model = "gpt-3.5-turbo-0125"
    return get_resp_oai(input_text, model)

response2 = data_transformations()

# %%
display(Markdown("<div style='color: #34568B;'>\n\n" + response2))
# Out:
# <div style='color: #34568B;'>
#
# ---
#
# ```python
# import pandas as pd
#
# # Read the merged dataset
# merged_data = pd.read_csv('merged_datasets.csv')
#
# # Convert budget object values to numeric
# merged_data['budget'] = pd.to_numeric(merged_data['budget'], errors='coerce')
#
# # Create dummy variables for genre type
# genre_dummies = pd.get_dummies(merged_data['genres_x'].str.get_dummies(sep='|'))
#
# # Observing categorical variable counts
# genre_counts = merged_data['genres_x'].value_counts()
# director_counts = merged_data['director_name'].value_counts()
# actor1_counts = merged_data['actor_1_name'].value_counts()
# actor2_counts = merged_data['actor_2_name'].value_counts()
# actor3_counts = merged_data['actor_3_name'].value_counts()
# country_counts = merged_data['country'].value_counts()
# ```
#
# ---

# %%
exec(response2[len("---\n\n```python\n"):len(response2)-len("\n```\n\n--")])

# %%
# not sure what you wan to do here
# #Cell 2.1: Perform Dataset Checks
# def dataset_checks():
#     # Counting  number of NAN values present in the merged dataframes 1 and 3
#     nan_count_df1 = pd.read_csv("movies_dataset1.csv").isnull().sum().sum()
#     nan_count_df3 = pd.read_csv("movies_dataset3.csv").isnull().sum().sum()

#     result_text = f"Number of NaN values in merged dataframe 1: {nan_count_df1}\nNumber of NaN values in merged dataframe 3: {nan_count_df3}"
#     return result_text

# dataset_checks()
# Out:
# /tmp/ipykernel_71/4112029611.py:5: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   nan_count_df3 = pd.read_csv("movies_dataset3.csv").isnull().sum().sum()
# 'Number of NaN values in merged dataframe 1: 308\nNumber of NaN values in merged dataframe 3: 105562'

# %%
# not sure what you wan to do here
# # Cell 2.2: Rename Merged DataFrame and Observe Variables
# def rename_and_observe():
#     input_text = "```python\nfinal_merged_df = dataset1.merge(dataset3, on='common_column')\nprint(final_merged_df.info())\n```\n\n---"
#     model = "gpt-3.5-turbo-0125"
#     return get_resp_oai(input_text, model)

# # Call the function to rename the merged dataframe and observe variables
# rename_and_observe()
# Out:
# '---\n\nThis code snippet merges two datasets, `dataset1` and `dataset3`, on a common column and then prints information about the merged dataset using the `info()` method. The `info()` method provides a concise summary of the merged dataset including the column names, non-null counts, and data types for each column.\n\n---'

# %%
#Cell 2.3: Data Transformations
def data_transformations():
    input_text = """
    provide code to perform the following transformations for merged_data dataframe,
    merged_data columns = ['index',
 'director_name',
 'duration',
 'actor_2_name',
 'actor_1_name',
 'movie_title',
 'num_voted_users',
 'actor_3_name',
 'movie_imdb_link',
 'num_user_for_reviews',
 'language',
 'country',
 'title_year',
 'imdb_score',
 'adult',
 'belongs_to_collection',
 'budget',
 'genres_y',
 'homepage',
 'original_language',
 'popularity',
 'production_companies',
 'production_countries',
 'revenue',
 'runtime',
 'spoken_languages',
 'status',
 'title',
 'vote_average',
 'vote_count',
 'release_year',
 'genre_Action',
 'genre_Action|Adventure',
 'genre_Action|Adventure|Animation|Comedy|Crime|Family|Fantasy',
 'genre_Action|Adventure|Animation|Comedy|Drama|Family|Sci-Fi',
 'genre_Action|Adventure|Animation|Comedy|Family',
 'genre_Action|Adventure|Animation|Comedy|Family|Fantasy',
 'genre_Action|Adventure|Animation|Comedy|Family|Fantasy|Sci-Fi',
 'genre_Action|Adventure|Animation|Comedy|Family|Sci-Fi',
 'genre_Action|Adventure|Animation|Comedy|Fantasy|Sci-Fi',
 'genre_Action|Adventure|Animation|Drama|Mystery|Sci-Fi|Thriller',
 'genre_Action|Adventure|Animation|Family',
 'genre_Action|Adventure|Animation|Family|Fantasy',
 'genre_Action|Adventure|Animation|Family|Fantasy|Sci-Fi',
 'genre_Action|Adventure|Animation|Family|Sci-Fi',
 'genre_Action|Adventure|Animation|Family|Sci-Fi|Thriller',
 'genre_Action|Adventure|Animation|Fantasy',
 'genre_Action|Adventure|Animation|Fantasy|Romance|Sci-Fi',
 'genre_Action|Adventure|Biography|Drama|History|Romance|War',
 'genre_Action|Adventure|Biography|Drama|History|Thriller',
 'genre_Action|Adventure|Comedy',
 'genre_Action|Adventure|Comedy|Crime',
 'genre_Action|Adventure|Comedy|Crime|Family|Romance|Thriller',
 'genre_Action|Adventure|Comedy|Crime|Music|Mystery',
 'genre_Action|Adventure|Comedy|Crime|Mystery|Thriller',
 'genre_Action|Adventure|Comedy|Crime|Thriller',
 'genre_Action|Adventure|Comedy|Drama|Music|Sci-Fi',
 'genre_Action|Adventure|Comedy|Drama|Thriller',
 'genre_Action|Adventure|Comedy|Drama|War',
 'genre_Action|Adventure|Comedy|Family',
 'genre_Action|Adventure|Comedy|Family|Fantasy',
 'genre_Action|Adventure|Comedy|Family|Fantasy|Mystery|Sci-Fi',
 'genre_Action|Adventure|Comedy|Family|Fantasy|Sci-Fi',
 'genre_Action|Adventure|Comedy|Family|Mystery',
 'genre_Action|Adventure|Comedy|Family|Romance',
 'genre_Action|Adventure|Comedy|Family|Romance|Sci-Fi',
 'genre_Action|Adventure|Comedy|Family|Sci-Fi',
 'genre_Action|Adventure|Comedy|Fantasy',
 'genre_Action|Adventure|Comedy|Fantasy|Mystery',
 'genre_Action|Adventure|Comedy|Fantasy|Romance',
 'genre_Action|Adventure|Comedy|Fantasy|Thriller',
 'genre_Action|Adventure|Comedy|Musical',
 'genre_Action|Adventure|Comedy|Music|Thriller',
 'genre_Action|Adventure|Comedy|Romance',
 'genre_Action|Adventure|Comedy|Romance|Sci-Fi',
 'genre_Action|Adventure|Comedy|Romance|Thriller',
 'genre_Action|Adventure|Comedy|Romance|Thriller|Western',
 'genre_Action|Adventure|Comedy|Sci-Fi',
 'genre_Action|Adventure|Comedy|Sci-Fi|Thriller',
 'genre_Action|Adventure|Comedy|Thriller',
 'genre_Action|Adventure|Comedy|Western',
 'genre_Action|Adventure|Crime|Drama',
 'genre_Action|Adventure|Crime|Drama|Family|Fantasy|Romance|Thriller',
 'genre_Action|Adventure|Crime|Drama|Mystery|Thriller',
 'genre_Action|Adventure|Crime|Drama|Romance',
 'genre_Action|Adventure|Crime|Drama|Thriller',
 'genre_Action|Adventure|Crime|Fantasy|Mystery|Thriller',
 'genre_Action|Adventure|Crime|Mystery|Thriller',
 'genre_Action|Adventure|Crime|Thriller',
 'genre_Action|Adventure|Drama',
 'genre_Action|Adventure|Drama|Family',
 'genre_Action|Adventure|Drama|Fantasy',
 'genre_Action|Adventure|Drama|Fantasy|Sci-Fi',
 'genre_Action|Adventure|Drama|Fantasy|War',
 'genre_Action|Adventure|Drama|History',
 'genre_Action|Adventure|Drama|History|Romance',
 'genre_Action|Adventure|Drama|History|Romance|War',
 'genre_Action|Adventure|Drama|History|Thriller|War',
 'genre_Action|Adventure|Drama|History|War',
 'genre_Action|Adventure|Drama|Mystery',
 'genre_Action|Adventure|Drama|Romance',
 'genre_Action|Adventure|Drama|Romance|Sci-Fi',
 'genre_Action|Adventure|Drama|Romance|Thriller',
 'genre_Action|Adventure|Drama|Romance|War',
 'genre_Action|Adventure|Drama|Romance|Western',
 'genre_Action|Adventure|Drama|Sci-Fi',
 'genre_Action|Adventure|Drama|Sci-Fi|Thriller',
 'genre_Action|Adventure|Drama|Thriller',
 'genre_Action|Adventure|Drama|Thriller|War',
 'genre_Action|Adventure|Drama|Thriller|Western',
 'genre_Action|Adventure|Drama|War',
 'genre_Action|Adventure|Drama|Western',
 'genre_Action|Adventure|Family|Fantasy',
 'genre_Action|Adventure|Family|Fantasy|Romance',
 'genre_Action|Adventure|Family|Fantasy|Sci-Fi',
 'genre_Action|Adventure|Family|Fantasy|Sci-Fi|Thriller',
 'genre_Action|Adventure|Family|Fantasy|Thriller',
 'genre_Action|Adventure|Family|Mystery',
 'genre_Action|Adventure|Family|Mystery|Sci-Fi',
 'genre_Action|Adventure|Family|Sci-Fi',
 'genre_Action|Adventure|Family|Sci-Fi|Thriller',
 'genre_Action|Adventure|Fantasy',
 'genre_Action|Adventure|Fantasy|Horror',
 'genre_Action|Adventure|Fantasy|Horror|Sci-Fi',
 'genre_Action|Adventure|Fantasy|Horror|Sci-Fi|Thriller',
 'genre_Action|Adventure|Fantasy|Horror|Thriller',
 'genre_Action|Adventure|Fantasy|Romance',
 'genre_Action|Adventure|Fantasy|Sci-Fi',
 'genre_Action|Adventure|Fantasy|Sci-Fi|Thriller',
 'genre_Action|Adventure|Fantasy|Thriller',
 'genre_Action|Adventure|Fantasy|War',
 'genre_Action|Adventure|History',
 'genre_Action|Adventure|History|Romance',
 'genre_Action|Adventure|History|Western',
 'genre_Action|Adventure|Horror|Sci-Fi',
 'genre_Action|Adventure|Horror|Sci-Fi|Thriller',
 'genre_Action|Adventure|Horror|Thriller',
 'genre_Action|Adventure|Mystery|Sci-Fi',
 'genre_Action|Adventure|Mystery|Sci-Fi|Thriller',
 'genre_Action|Adventure|Romance',
 'genre_Action|Adventure|Romance|Sci-Fi',
 'genre_Action|Adventure|Romance|Sci-Fi|Thriller',
 'genre_Action|Adventure|Romance|Thriller',
 'genre_Action|Adventure|Romance|War',
 'genre_Action|Adventure|Romance|Western',
 'genre_Action|Adventure|Sci-Fi',
 'genre_Action|Adventure|Sci-Fi|Thriller',
 'genre_Action|Adventure|Thriller',
 'genre_Action|Adventure|Thriller|War',
 'genre_Action|Adventure|Western',
 'genre_Action|Animation|Comedy|Crime|Family',
 'genre_Action|Animation|Comedy|Family',
 'genre_Action|Animation|Comedy|Family|Fantasy',
 'genre_Action|Animation|Comedy|Family|Sci-Fi',
 'genre_Action|Animation|Comedy|Sci-Fi',
 'genre_Action|Animation|Crime|Sci-Fi|Thriller',
 'genre_Action|Animation|Fantasy|Horror|Mystery|Sci-Fi|Thriller',
 'genre_Action|Animation|Sci-Fi|Thriller',
 'genre_Action|Biography|Crime|Drama',
 'genre_Action|Biography|Crime|Drama|Family|Fantasy',
 'genre_Action|Biography|Crime|Drama|Thriller',
 'genre_Action|Biography|Drama|History|Romance|War',
 'genre_Action|Biography|Drama|History|Romance|Western',
 'genre_Action|Biography|Drama|History|Thriller|War',
 'genre_Action|Biography|Drama|History|War',
 'genre_Action|Biography|Drama|Sport',
 'genre_Action|Biography|Drama|Thriller|War',
 'genre_Action|Comedy',
 'genre_Action|Comedy|Crime',
 'genre_Action|Comedy|Crime|Drama',
 'genre_Action|Comedy|Crime|Drama|Romance|Thriller',
 'genre_Action|Comedy|Crime|Drama|Thriller',
 'genre_Action|Comedy|Crime|Family',
 'genre_Action|Comedy|Crime|Fantasy',
 'genre_Action|Comedy|Crime|Music',
 'genre_Action|Comedy|Crime|Music|Romance|Thriller',
 'genre_Action|Comedy|Crime|Romance',
 'genre_Action|Comedy|Crime|Romance|Thriller',
 'genre_Action|Comedy|Crime|Sci-Fi|Thriller',
 'genre_Action|Comedy|Crime|Thriller',
 'genre_Action|Comedy|Crime|Western',
 'genre_Action|Comedy|Documentary',
 'genre_Action|Comedy|Drama',
 'genre_Action|Comedy|Drama|Family|Thriller',
 'genre_Action|Comedy|Drama|Music',
 'genre_Action|Comedy|Drama|Sci-Fi',
 'genre_Action|Comedy|Drama|Thriller',
 'genre_Action|Comedy|Drama|Western',
 'genre_Action|Comedy|Family',
 'genre_Action|Comedy|Family|Fantasy',
 'genre_Action|Comedy|Fantasy',
 'genre_Action|Comedy|Fantasy|Romance',
 'genre_Action|Comedy|Fantasy|Sci-Fi',
 'genre_Action|Comedy|Horror',
 'genre_Action|Comedy|Horror|Sci-Fi',
 'genre_Action|Comedy|Horror|Thriller',
 'genre_Action|Comedy|Music',
 'genre_Action|Comedy|Mystery',
 'genre_Action|Comedy|Mystery|Romance',
 'genre_Action|Comedy|Romance',
 'genre_Action|Comedy|Romance|Thriller',
 'genre_Action|Comedy|Sci-Fi',
 'genre_Action|Comedy|Sci-Fi|Sport',
 'genre_Action|Comedy|Sci-Fi|Thriller',
 'genre_Action|Comedy|Sci-Fi|Western',
 'genre_Action|Comedy|Sport',
 'genre_Action|Comedy|Thriller',
 'genre_Action|Comedy|War',
 'genre_Action|Crime',
 'genre_Action|Crime|Drama',
 'genre_Action|Crime|Drama|History|Western',
 'genre_Action|Crime|Drama|Mystery|Sci-Fi|Thriller',
 'genre_Action|Crime|Drama|Mystery|Thriller',
 'genre_Action|Crime|Drama|Romance|Thriller',
 'genre_Action|Crime|Drama|Sci-Fi|Thriller',
 'genre_Action|Crime|Drama|Sport',
 'genre_Action|Crime|Drama|Thriller',
 'genre_Action|Crime|Drama|Thriller|War',
 'genre_Action|Crime|Drama|Thriller|Western',
 'genre_Action|Crime|Drama|Western',
 'genre_Action|Crime|Fantasy|Romance|Thriller',
 'genre_Action|Crime|Fantasy|Thriller',
 'genre_Action|Crime|Horror|Sci-Fi|Thriller',
 'genre_Action|Crime|Horror|Thriller',
 'genre_Action|Crime|Mystery|Romance|Thriller',
 'genre_Action|Crime|Mystery|Sci-Fi|Thriller',
 'genre_Action|Crime|Mystery|Thriller',
 'genre_Action|Crime|Romance|Thriller',
 'genre_Action|Crime|Sci-Fi',
 'genre_Action|Crime|Sci-Fi|Thriller',
 'genre_Action|Crime|Sport|Thriller',
 'genre_Action|Crime|Thriller',
 'genre_Action|Drama',
 'genre_Action|Drama|Family|Sport',
 'genre_Action|Drama|Fantasy',
 'genre_Action|Drama|Fantasy|Horror|War',
 'genre_Action|Drama|Fantasy|Mystery|Sci-Fi|Thriller',
 'genre_Action|Drama|Fantasy|Mystery|Thriller',
 'genre_Action|Drama|Fantasy|Romance',
 'genre_Action|Drama|Fantasy|Sci-Fi',
 'genre_Action|Drama|Fantasy|Thriller|Western',
 'genre_Action|Drama|Fantasy|War',
 'genre_Action|Drama|History|Romance|War',
 'genre_Action|Drama|History|Romance|War|Western',
 'genre_Action|Drama|History|Thriller',
 'genre_Action|Drama|History|Thriller|War',
 'genre_Action|Drama|History|War',
 'genre_Action|Drama|Horror|Thriller',
 'genre_Action|Drama|Music|Romance',
 'genre_Action|Drama|Mystery|Sci-Fi',
 'genre_Action|Drama|Mystery|Thriller',
 'genre_Action|Drama|Mystery|Thriller|War',
 'genre_Action|Drama|Romance',
 'genre_Action|Drama|Romance|Sci-Fi|Thriller',
 'genre_Action|Drama|Romance|Sport',
 'genre_Action|Drama|Romance|Thriller',
 'genre_Action|Drama|Romance|War',
 'genre_Action|Drama|Sci-Fi',
 'genre_Action|Drama|Sci-Fi|Sport',
 'genre_Action|Drama|Sci-Fi|Thriller',
 'genre_Action|Drama|Sport',
 'genre_Action|Drama|Sport|Thriller',
 'genre_Action|Drama|Thriller',
 'genre_Action|Drama|Thriller|War',
 'genre_Action|Drama|War',
 'genre_Action|Drama|Western',
 'genre_Action|Family|Sport',
 'genre_Action|Fantasy',
 'genre_Action|Fantasy|Horror',
 'genre_Action|Fantasy|Horror|Mystery',
 'genre_Action|Fantasy|Horror|Mystery|Thriller',
 'genre_Action|Fantasy|Horror|Sci-Fi',
 'genre_Action|Fantasy|Horror|Sci-Fi|Thriller',
 'genre_Action|Fantasy|Horror|Thriller',
 'genre_Action|Fantasy|Sci-Fi|Thriller',
 'genre_Action|Fantasy|Thriller',
 'genre_Action|Fantasy|Western',
 'genre_Action|Horror',
 'genre_Action|Horror|Mystery|Sci-Fi|Thriller',
 'genre_Action|Horror|Mystery|Thriller',
 'genre_Action|Horror|Romance',
 'genre_Action|Horror|Romance|Sci-Fi|Thriller',
 'genre_Action|Horror|Sci-Fi',
 'genre_Action|Horror|Sci-Fi|Thriller',
 'genre_Action|Horror|Thriller',
 'genre_Action|Mystery|Sci-Fi|Thriller',
 'genre_Action|Mystery|Thriller',
 'genre_Action|Romance|Thriller',
 'genre_Action|Sci-Fi',
 'genre_Action|Sci-Fi|Sport',
 'genre_Action|Sci-Fi|Thriller',
 'genre_Action|Sci-Fi|War',
 'genre_Action|Sport',
 'genre_Action|Thriller',
 'genre_Action|Thriller|Western',
 'genre_Action|War',
 'genre_Action|Western',
 'genre_Adventure',
 'genre_Adventure|Animation|Biography|Drama|Family|Fantasy|Musical',
 'genre_Adventure|Animation|Comedy',
 'genre_Adventure|Animation|Comedy|Crime',
 'genre_Adventure|Animation|Comedy|Crime|Family',
 'genre_Adventure|Animation|Comedy|Drama|Family',
 'genre_Adventure|Animation|Comedy|Drama|Family|Fantasy',
 'genre_Adventure|Animation|Comedy|Drama|Family|Fantasy|Romance',
 'genre_Adventure|Animation|Comedy|Drama|Family|Fantasy|Sci-Fi',
 'genre_Adventure|Animation|Comedy|Drama|Family|Musical',
 'genre_Adventure|Animation|Comedy|Family',
 'genre_Adventure|Animation|Comedy|Family|Fantasy',
 'genre_Adventure|Animation|Comedy|Family|Fantasy|Music',
 'genre_Adventure|Animation|Comedy|Family|Fantasy|Musical',
 'genre_Adventure|Animation|Comedy|Family|Fantasy|Musical|Romance',
 'genre_Adventure|Animation|Comedy|Family|Fantasy|Romance',
 'genre_Adventure|Animation|Comedy|Family|Fantasy|Sci-Fi',
 'genre_Adventure|Animation|Comedy|Family|Fantasy|Sci-Fi|Sport',
 'genre_Adventure|Animation|Comedy|Family|Musical',
 'genre_Adventure|Animation|Comedy|Family|Romance',
 'genre_Adventure|Animation|Comedy|Family|Sci-Fi',
 'genre_Adventure|Animation|Comedy|Family|Sport',
 'genre_Adventure|Animation|Comedy|Family|War',
 'genre_Adventure|Animation|Comedy|Family|Western',
 'genre_Adventure|Animation|Comedy|Fantasy',
 'genre_Adventure|Animation|Comedy|Fantasy|Romance',
 'genre_Adventure|Animation|Drama|Family|Fantasy',
 'genre_Adventure|Animation|Drama|Family|Fantasy|Musical|Mystery|Romance',
 'genre_Adventure|Animation|Drama|Family|History|Musical|Romance',
 'genre_Adventure|Animation|Drama|Family|Musical',
 'genre_Adventure|Animation|Family',
 'genre_Adventure|Animation|Family|Fantasy',
 'genre_Adventure|Animation|Family|Fantasy|Musical',
 'genre_Adventure|Animation|Family|Fantasy|Musical|War',
 'genre_Adventure|Animation|Family|Musical',
 'genre_Adventure|Animation|Family|Sci-Fi',
 'genre_Adventure|Animation|Family|Thriller',
 'genre_Adventure|Animation|Family|Western',
 'genre_Adventure|Animation|Fantasy|Horror|Sci-Fi',
 'genre_Adventure|Biography',
 'genre_Adventure|Biography|Crime|Drama|Western',
 'genre_Adventure|Biography|Documentary|Drama',
 'genre_Adventure|Biography|Drama',
 'genre_Adventure|Biography|Drama|History',
 'genre_Adventure|Biography|Drama|History|Sport|Thriller',
 'genre_Adventure|Biography|Drama|History|War',
 'genre_Adventure|Biography|Drama|Thriller',
 'genre_Adventure|Biography|Drama|War',
 'genre_Adventure|Comedy',
 'genre_Adventure|Comedy|Crime',
 'genre_Adventure|Comedy|Crime|Drama',
 'genre_Adventure|Comedy|Crime|Drama|Family',
 'genre_Adventure|Comedy|Crime|Family|Musical',
 'genre_Adventure|Comedy|Crime|Family|Mystery',
 'genre_Adventure|Comedy|Crime|Music',
 'genre_Adventure|Comedy|Crime|Romance',
 'genre_Adventure|Comedy|Drama',
 'genre_Adventure|Comedy|Drama|Family',
 'genre_Adventure|Comedy|Drama|Family|Fantasy',
 'genre_Adventure|Comedy|Drama|Family|Mystery',
 'genre_Adventure|Comedy|Drama|Family|Romance',
 'genre_Adventure|Comedy|Drama|Family|Sport',
 'genre_Adventure|Comedy|Drama|Fantasy',
 'genre_Adventure|Comedy|Drama|Fantasy|Musical',
 'genre_Adventure|Comedy|Drama|Fantasy|Romance',
 'genre_Adventure|Comedy|Drama|Music',
 'genre_Adventure|Comedy|Drama|Romance',
 'genre_Adventure|Comedy|Drama|Romance|Sci-Fi',
 'genre_Adventure|Comedy|Drama|Romance|Thriller|War',
 'genre_Adventure|Comedy|Family',
 'genre_Adventure|Comedy|Family|Fantasy',
 'genre_Adventure|Comedy|Family|Fantasy|Horror',
 'genre_Adventure|Comedy|Family|Fantasy|Horror|Mystery',
 'genre_Adventure|Comedy|Family|Fantasy|Musical',
 'genre_Adventure|Comedy|Family|Fantasy|Music|Sci-Fi',
 'genre_Adventure|Comedy|Family|Fantasy|Romance|Sport',
 'genre_Adventure|Comedy|Family|Fantasy|Sci-Fi',
 'genre_Adventure|Comedy|Family|Musical',
 'genre_Adventure|Comedy|Family|Music|Romance',
 'genre_Adventure|Comedy|Family|Mystery|Sci-Fi',
 'genre_Adventure|Comedy|Family|Romance',
 'genre_Adventure|Comedy|Family|Romance|Sci-Fi',
 'genre_Adventure|Comedy|Family|Sci-Fi',
 'genre_Adventure|Comedy|Family|Sport',
 'genre_Adventure|Comedy|Fantasy',
 'genre_Adventure|Comedy|Fantasy|Music|Sci-Fi',
 'genre_Adventure|Comedy|Fantasy|Sci-Fi',
 'genre_Adventure|Comedy|History',
 'genre_Adventure|Comedy|History|Romance',
 'genre_Adventure|Comedy|Horror',
 'genre_Adventure|Comedy|Horror|Sci-Fi',
 'genre_Adventure|Comedy|Musical|Romance',
 'genre_Adventure|Comedy|Music|Sci-Fi',
 'genre_Adventure|Comedy|Mystery',
 'genre_Adventure|Comedy|Romance',
 'genre_Adventure|Comedy|Romance|Sci-Fi',
 'genre_Adventure|Comedy|Sci-Fi',
 'genre_Adventure|Comedy|Sci-Fi|Western',
 'genre_Adventure|Comedy|Sport',
 'genre_Adventure|Crime|Drama|Mystery|Thriller',
 'genre_Adventure|Crime|Drama|Romance',
 'genre_Adventure|Crime|Drama|Western',
 'genre_Adventure|Crime|Mystery|Sci-Fi|Thriller',
 'genre_Adventure|Crime|Thriller',
 'genre_Adventure|Documentary|Drama|Sport',
 'genre_Adventure|Drama',
 'genre_Adventure|Drama|Family',
 'genre_Adventure|Drama|Family|Fantasy',
 'genre_Adventure|Drama|Family|Fantasy|Sci-Fi',
 'genre_Adventure|Drama|Family|Mystery',
 'genre_Adventure|Drama|Family|Romance|Western',
 'genre_Adventure|Drama|Fantasy',
 'genre_Adventure|Drama|Fantasy|Romance',
 'genre_Adventure|Drama|History',
 'genre_Adventure|Drama|History|Romance',
 'genre_Adventure|Drama|History|Romance|War',
 'genre_Adventure|Drama|History|Thriller|War',
 'genre_Adventure|Drama|History|War',
 'genre_Adventure|Drama|Horror|Mystery|Thriller',
 'genre_Adventure|Drama|Horror|Thriller',
 'genre_Adventure|Drama|Mystery',
 'genre_Adventure|Drama|Romance',
 'genre_Adventure|Drama|Romance|War',
 'genre_Adventure|Drama|Romance|Western',
 'genre_Adventure|Drama|Sci-Fi',
 'genre_Adventure|Drama|Sci-Fi|Thriller',
 'genre_Adventure|Drama|Thriller',
 'genre_Adventure|Drama|Thriller|War',
 'genre_Adventure|Drama|Thriller|Western',
 'genre_Adventure|Drama|War',
 'genre_Adventure|Drama|Western',
 'genre_Adventure|Family',
 'genre_Adventure|Family|Fantasy',
 'genre_Adventure|Family|Fantasy|Horror|Mystery',
 'genre_Adventure|Family|Fantasy|Musical',
 'genre_Adventure|Family|Fantasy|Music|Musical',
 'genre_Adventure|Family|Fantasy|Mystery',
 'genre_Adventure|Family|Fantasy|Romance',
 'genre_Adventure|Family|Fantasy|Sci-Fi',
 'genre_Adventure|Family|Romance',
 'genre_Adventure|Family|Sci-Fi',
 'genre_Adventure|Family|Sport',
 'genre_Adventure|Fantasy',
 'genre_Adventure|Fantasy|Horror|Mystery|Thriller',
 'genre_Adventure|Fantasy|Mystery',
 'genre_Adventure|Fantasy|Mystery|Thriller',
 'genre_Adventure|Fantasy|Thriller',
 'genre_Adventure|Horror',
 'genre_Adventure|Horror|Mystery',
 'genre_Adventure|Horror|Sci-Fi',
 'genre_Adventure|Horror|Thriller',
 'genre_Adventure|Mystery|Sci-Fi',
 'genre_Adventure|Mystery|Thriller',
 'genre_Adventure|Sci-Fi',
 'genre_Adventure|Sci-Fi|Thriller',
 'genre_Adventure|War|Western',
 'genre_Animation|Biography|Drama|War',
 'genre_Animation|Comedy',
 'genre_Animation|Comedy|Drama|Family|Musical',
 'genre_Animation|Comedy|Drama|Romance',
 'genre_Animation|Comedy|Family',
 'genre_Animation|Comedy|Family|Fantasy',
 'genre_Animation|Comedy|Family|Fantasy|Music',
 'genre_Animation|Comedy|Family|Fantasy|Musical',
 'genre_Animation|Comedy|Family|Fantasy|Musical|Romance',
 'genre_Animation|Comedy|Family|Fantasy|Mystery',
 'genre_Animation|Comedy|Family|Fantasy|Sci-Fi',
 'genre_Animation|Comedy|Family|Horror|Sci-Fi',
 'genre_Animation|Comedy|Family|Music|Romance',
 'genre_Animation|Comedy|Family|Music|Western',
 'genre_Animation|Comedy|Family|Mystery|Sci-Fi',
 'genre_Animation|Comedy|Family|Sci-Fi',
 'genre_Animation|Comedy|Family|Sport',
 'genre_Animation|Comedy|Fantasy',
 'genre_Animation|Comedy|Fantasy|Musical',
 'genre_Animation|Drama',
 'genre_Animation|Drama|Family',
 'genre_Animation|Drama|Family|Fantasy',
 'genre_Animation|Drama|Family|Fantasy|Musical|Romance',
 'genre_Animation|Drama|Family|Musical|Romance',
 'genre_Animation|Drama|Mystery|Sci-Fi|Thriller',
 'genre_Animation|Family|Fantasy',
 'genre_Animation|Family|Fantasy|Music',
 'genre_Animation|Family|Fantasy|Musical',
 'genre_Animation|Family|Fantasy|Musical|Romance',
 'genre_Animation|Family|Fantasy|Mystery',
 'genre_Biography|Comedy|Crime|Drama',
 'genre_Biography|Comedy|Crime|Drama|Romance',
 'genre_Biography|Comedy|Crime|Drama|Romance|Thriller',
 'genre_Biography|Comedy|Documentary',
 'genre_Biography|Comedy|Drama',
 'genre_Biography|Comedy|Drama|Family|Romance',
 'genre_Biography|Comedy|Drama|Family|Sport',
 'genre_Biography|Comedy|Drama|History',
 'genre_Biography|Comedy|Drama|History|Music',
 'genre_Biography|Comedy|Drama|History|Music|Musical',
 'genre_Biography|Comedy|Drama|Music',
 'genre_Biography|Comedy|Drama|Music|Romance',
 'genre_Biography|Comedy|Drama|Romance',
 'genre_Biography|Comedy|Drama|Sport',
 'genre_Biography|Comedy|Drama|War',
 'genre_Biography|Comedy|Musical',
 'genre_Biography|Comedy|Musical|Romance|Western',
 'genre_Biography|Comedy|Romance',
 'genre_Biography|Crime|Documentary|History|Thriller',
 'genre_Biography|Crime|Drama',
 'genre_Biography|Crime|Drama|History',
 'genre_Biography|Crime|Drama|History|Music',
 'genre_Biography|Crime|Drama|History|Romance',
 'genre_Biography|Crime|Drama|History|Thriller',
 'genre_Biography|Crime|Drama|History|Western',
 'genre_Biography|Crime|Drama|Music',
 'genre_Biography|Crime|Drama|Mystery|Thriller',
 'genre_Biography|Crime|Drama|Romance',
 'genre_Biography|Crime|Drama|Romance|Thriller',
 'genre_Biography|Crime|Drama|Thriller',
 'genre_Biography|Crime|Drama|War',
 'genre_Biography|Crime|Drama|Western',
 'genre_Biography|Documentary',
 'genre_Biography|Documentary|Drama',
 'genre_Biography|Documentary|History',
 'genre_Biography|Documentary|Music',
 'genre_Biography|Documentary|Sport',
 'genre_Biography|Drama',
 'genre_Biography|Drama|Family',
 'genre_Biography|Drama|Family|History|Sport',
 'genre_Biography|Drama|Family|Musical|Romance',
 'genre_Biography|Drama|Family|Sport',
 'genre_Biography|Drama|History',
 'genre_Biography|Drama|History|Music',
 'genre_Biography|Drama|History|Musical',
 'genre_Biography|Drama|History|Romance',
 'genre_Biography|Drama|History|Sport',
 'genre_Biography|Drama|History|Thriller',
 'genre_Biography|Drama|History|Thriller|War',
 'genre_Biography|Drama|History|War',
 'genre_Biography|Drama|Music',
 'genre_Biography|Drama|Music|Musical',
 'genre_Biography|Drama|Music|Romance',
 'genre_Biography|Drama|Romance',
 'genre_Biography|Drama|Romance|Sport',
 'genre_Biography|Drama|Romance|War',
 'genre_Biography|Drama|Romance|Western',
 'genre_Biography|Drama|Sport',
 'genre_Biography|Drama|Sport|War',
 'genre_Biography|Drama|Thriller',
 'genre_Biography|Drama|Thriller|War',
 'genre_Biography|Drama|War',
 'genre_Comedy',
 'genre_Comedy|Crime',
 'genre_Comedy|Crime|Drama',
 'genre_Comedy|Crime|Drama|Horror|Mystery|Thriller',
 'genre_Comedy|Crime|Drama|Horror|Thriller',
 'genre_Comedy|Crime|Drama|Music|Romance',
 'genre_Comedy|Crime|Drama|Mystery',
 'genre_Comedy|Crime|Drama|Mystery|Romance',
 'genre_Comedy|Crime|Drama|Mystery|Thriller',
 'genre_Comedy|Crime|Drama|Romance',
 'genre_Comedy|Crime|Drama|Romance|Thriller',
 'genre_Comedy|Crime|Drama|Sci-Fi',
 'genre_Comedy|Crime|Drama|Thriller',
 'genre_Comedy|Crime|Drama|Thriller|War',
 'genre_Comedy|Crime|Family',
 'genre_Comedy|Crime|Family|Mystery|Romance|Thriller',
 'genre_Comedy|Crime|Family|Romance',
 'genre_Comedy|Crime|Family|Sci-Fi',
 'genre_Comedy|Crime|Horror',
 'genre_Comedy|Crime|Horror|Thriller',
 'genre_Comedy|Crime|Music',
 'genre_Comedy|Crime|Musical',
 'genre_Comedy|Crime|Musical|Mystery',
 'genre_Comedy|Crime|Mystery',
 'genre_Comedy|Crime|Mystery|Romance',
 'genre_Comedy|Crime|Romance',
 'genre_Comedy|Crime|Romance|Thriller',
 'genre_Comedy|Crime|Sci-Fi|Thriller',
 'genre_Comedy|Crime|Sport',
 'genre_Comedy|Crime|Thriller',
 'genre_Comedy|Documentary',
 'genre_Comedy|Documentary|Drama',
 'genre_Comedy|Documentary|Drama|Fantasy|Mystery|Sci-Fi',
 'genre_Comedy|Documentary|Music',
 'genre_Comedy|Documentary|War',
 'genre_Comedy|Drama',
 'genre_Comedy|Drama|Family',
 'genre_Comedy|Drama|Family|Fantasy',
 'genre_Comedy|Drama|Family|Fantasy|Musical',
 'genre_Comedy|Drama|Family|Fantasy|Romance',
 'genre_Comedy|Drama|Family|Fantasy|Sci-Fi',
 'genre_Comedy|Drama|Family|Musical',
 'genre_Comedy|Drama|Family|Music|Musical|Romance',
 'genre_Comedy|Drama|Family|Music|Romance',
 'genre_Comedy|Drama|Family|Romance',
 'genre_Comedy|Drama|Family|Sport',
 'genre_Comedy|Drama|Fantasy',
 'genre_Comedy|Drama|Fantasy|Music|Romance',
 'genre_Comedy|Drama|Fantasy|Romance',
 'genre_Comedy|Drama|History|Musical|Romance',
 'genre_Comedy|Drama|History|Romance',
 'genre_Comedy|Drama|Horror',
 'genre_Comedy|Drama|Horror|Romance',
 'genre_Comedy|Drama|Horror|Sci-Fi',
 'genre_Comedy|Drama|Music',
 'genre_Comedy|Drama|Musical',
 'genre_Comedy|Drama|Musical|Romance',
 'genre_Comedy|Drama|Musical|Romance|War',
 'genre_Comedy|Drama|Musical|Romance|Western',
 'genre_Comedy|Drama|Music|Musical',
 'genre_Comedy|Drama|Music|Musical|Romance',
 'genre_Comedy|Drama|Music|Romance',
 'genre_Comedy|Drama|Music|War',
 'genre_Comedy|Drama|Mystery|Romance|Thriller|War',
 'genre_Comedy|Drama|Romance',
 'genre_Comedy|Drama|Romance|Sci-Fi',
 'genre_Comedy|Drama|Romance|Sport',
 'genre_Comedy|Drama|Romance|Thriller',
 'genre_Comedy|Drama|Romance|Western',
 'genre_Comedy|Drama|Sci-Fi',
 'genre_Comedy|Drama|Sport',
 'genre_Comedy|Drama|Thriller',
 'genre_Comedy|Drama|War',
 'genre_Comedy|Family',
 'genre_Comedy|Family|Fantasy',
 'genre_Comedy|Family|Fantasy|Horror|Mystery',
 'genre_Comedy|Family|Fantasy|Musical',
 'genre_Comedy|Family|Fantasy|Music|Romance',
 'genre_Comedy|Family|Fantasy|Romance',
 'genre_Comedy|Family|Fantasy|Sport',
 'genre_Comedy|Family|Music',
 'genre_Comedy|Family|Musical|Romance',
 'genre_Comedy|Family|Music|Musical',
 'genre_Comedy|Family|Music|Romance',
 'genre_Comedy|Family|Romance',
 'genre_Comedy|Family|Romance|Sci-Fi',
 'genre_Comedy|Family|Romance|Sport',
 'genre_Comedy|Family|Sci-Fi',
 'genre_Comedy|Family|Sport',
 'genre_Comedy|Fantasy',
 'genre_Comedy|Fantasy|Horror',
 'genre_Comedy|Fantasy|Horror|Musical',
 'genre_Comedy|Fantasy|Horror|Mystery',
 'genre_Comedy|Fantasy|Horror|Romance',
 'genre_Comedy|Fantasy|Horror|Thriller',
 'genre_Comedy|Fantasy|Romance',
 'genre_Comedy|Fantasy|Sci-Fi',
 'genre_Comedy|Fantasy|Thriller',
 'genre_Comedy|History',
 'genre_Comedy|Horror',
 'genre_Comedy|Horror|Musical',
 'genre_Comedy|Horror|Musical|Sci-Fi',
 'genre_Comedy|Horror|Mystery',
 'genre_Comedy|Horror|Romance',
 'genre_Comedy|Horror|Sci-Fi',
 'genre_Comedy|Horror|Sci-Fi|Thriller',
 'genre_Comedy|Horror|Thriller',
 'genre_Comedy|Music',
 'genre_Comedy|Musical',
 'genre_Comedy|Musical|Romance',
 'genre_Comedy|Music|Romance',
 'genre_Comedy|Mystery',
 'genre_Comedy|Mystery|Romance',
 'genre_Comedy|Mystery|Sci-Fi|Thriller',
 'genre_Comedy|Mystery|Thriller',
 'genre_Comedy|Romance',
 'genre_Comedy|Romance|Sci-Fi',
 'genre_Comedy|Romance|Sci-Fi|Thriller',
 'genre_Comedy|Romance|Sport',
 'genre_Comedy|Romance|Thriller',
 'genre_Comedy|Sci-Fi',
 'genre_Comedy|Sci-Fi|Thriller',
 'genre_Comedy|Sport',
 'genre_Comedy|Thriller',
 'genre_Comedy|War',
 'genre_Comedy|Western',
 'genre_Crime|Documentary',
 'genre_Crime|Documentary|Drama',
 'genre_Crime|Documentary|News',
 'genre_Crime|Documentary|War',
 'genre_Crime|Drama',
 'genre_Crime|Drama|Fantasy',
 'genre_Crime|Drama|Fantasy|Mystery',
 'genre_Crime|Drama|Fantasy|Romance',
 'genre_Crime|Drama|Film-Noir',
 'genre_Crime|Drama|Film-Noir|Mystery|Thriller',
 'genre_Crime|Drama|History',
 'genre_Crime|Drama|History|Mystery|Thriller',
 'genre_Crime|Drama|Horror',
 'genre_Crime|Drama|Horror|Mystery|Thriller',
 'genre_Crime|Drama|Horror|Thriller',
 'genre_Crime|Drama|Music',
 'genre_Crime|Drama|Musical',
 'genre_Crime|Drama|Musical|Romance',
 'genre_Crime|Drama|Musical|Romance|Thriller',
 'genre_Crime|Drama|Music|Mystery|Thriller',
 'genre_Crime|Drama|Music|Romance',
 'genre_Crime|Drama|Music|Thriller',
 'genre_Crime|Drama|Mystery',
 'genre_Crime|Drama|Mystery|Romance|Thriller',
 'genre_Crime|Drama|Mystery|Sci-Fi|Thriller',
 'genre_Crime|Drama|Mystery|Thriller',
 'genre_Crime|Drama|Mystery|Thriller|Western',
 'genre_Crime|Drama|Romance',
 'genre_Crime|Drama|Romance|Thriller',
 'genre_Crime|Drama|Sport',
 'genre_Crime|Drama|Thriller',
 'genre_Crime|Drama|Western',
 'genre_Crime|Fantasy|Horror',
 'genre_Crime|Film-Noir|Thriller',
 'genre_Crime|Horror',
 'genre_Crime|Horror|Mystery|Thriller',
 'genre_Crime|Horror|Thriller',
 'genre_Crime|Mystery|Thriller',
 'genre_Crime|Romance|Thriller',
 'genre_Crime|Thriller',
 'genre_Crime|Thriller|War',
 'genre_Documentary',
 'genre_Documentary|Drama',
 'genre_Documentary|Drama|History|News',
 'genre_Documentary|Drama|Sport',
 'genre_Documentary|Drama|War',
 'genre_Documentary|Family|Music',
 'genre_Documentary|History',
 'genre_Documentary|History|Music',
 'genre_Documentary|History|Sport',
 'genre_Documentary|Music',
 'genre_Documentary|News',
 'genre_Documentary|Sport',
 'genre_Documentary|War',
 'genre_Drama',
 'genre_Drama|Family',
 'genre_Drama|Family|Fantasy',
 'genre_Drama|Family|Fantasy|Romance',
 'genre_Drama|Family|History|Musical',
 'genre_Drama|Family|Music',
 'genre_Drama|Family|Musical',
 'genre_Drama|Family|Musical|Romance',
 'genre_Drama|Family|Music|Musical',
 'genre_Drama|Family|Music|Romance',
 'genre_Drama|Family|Romance',
 'genre_Drama|Family|Sport',
 'genre_Drama|Family|Western',
 'genre_Drama|Fantasy',
 'genre_Drama|Fantasy|Horror',
 'genre_Drama|Fantasy|Horror|Mystery',
 'genre_Drama|Fantasy|Horror|Mystery|Thriller',
 'genre_Drama|Fantasy|Horror|Romance',
 'genre_Drama|Fantasy|Horror|Thriller',
 'genre_Drama|Fantasy|Musical|Romance',
 'genre_Drama|Fantasy|Music|Romance',
 'genre_Drama|Fantasy|Mystery|Romance',
 'genre_Drama|Fantasy|Mystery|Romance|Thriller',
 'genre_Drama|Fantasy|Mystery|Thriller',
 'genre_Drama|Fantasy|Romance',
 'genre_Drama|Fantasy|Romance|Sci-Fi',
 'genre_Drama|Fantasy|Romance|Thriller',
 'genre_Drama|Fantasy|Sci-Fi',
 'genre_Drama|Fantasy|Sport',
 'genre_Drama|Fantasy|Thriller',
 'genre_Drama|Film-Noir',
 'genre_Drama|Film-Noir|Mystery|Thriller',
 'genre_Drama|History',
 'genre_Drama|History|Horror',
 'genre_Drama|History|Romance',
 'genre_Drama|History|Romance|War',
 'genre_Drama|History|Romance|Western',
 'genre_Drama|History|Sport',
 'genre_Drama|History|Thriller',
 'genre_Drama|History|Thriller|War',
 'genre_Drama|History|War',
 'genre_Drama|History|War|Western',
 'genre_Drama|Horror',
 'genre_Drama|Horror|Mystery',
 'genre_Drama|Horror|Mystery|Sci-Fi|Thriller',
 'genre_Drama|Horror|Mystery|Thriller',
 'genre_Drama|Horror|Romance',
 'genre_Drama|Horror|Romance|Thriller',
 'genre_Drama|Horror|Sci-Fi',
 'genre_Drama|Horror|Sci-Fi|Thriller',
 'genre_Drama|Horror|Thriller',
 'genre_Drama|Music',
 'genre_Drama|Musical',
 'genre_Drama|Musical|Romance',
 'genre_Drama|Musical|Romance|Thriller',
 'genre_Drama|Musical|Sci-Fi',
 'genre_Drama|Music|Musical',
 'genre_Drama|Music|Musical|Romance',
 'genre_Drama|Music|Mystery|Romance',
 'genre_Drama|Music|Mystery|Romance|Sci-Fi',
 'genre_Drama|Music|Mystery|Romance|Thriller',
 'genre_Drama|Music|Romance',
 'genre_Drama|Music|Romance|War',
 'genre_Drama|Mystery',
 'genre_Drama|Mystery|Romance',
 'genre_Drama|Mystery|Romance|Sci-Fi|Thriller',
 'genre_Drama|Mystery|Romance|Thriller',
 'genre_Drama|Mystery|Romance|Thriller|War',
 'genre_Drama|Mystery|Romance|War',
 'genre_Drama|Mystery|Sci-Fi',
 'genre_Drama|Mystery|Sci-Fi|Thriller',
 'genre_Drama|Mystery|Thriller',
 'genre_Drama|Mystery|War',
 'genre_Drama|Romance',
 'genre_Drama|Romance|Sci-Fi',
 'genre_Drama|Romance|Sci-Fi|Thriller',
 'genre_Drama|Romance|Sport',
 'genre_Drama|Romance|Thriller',
 'genre_Drama|Romance|War',
 'genre_Drama|Romance|War|Western',
 'genre_Drama|Romance|Western',
 'genre_Drama|Sci-Fi',
 'genre_Drama|Sci-Fi|Thriller',
 'genre_Drama|Sport',
 'genre_Drama|Thriller',
 'genre_Drama|Thriller|War',
 'genre_Drama|War',
 'genre_Drama|Western',
 'genre_Family|Fantasy|Music',
 'genre_Family|Fantasy|Musical',
 'genre_Family|Musical',
 'genre_Family|Music|Romance',
 'genre_Family|Sci-Fi',
 'genre_Fantasy',
 'genre_Fantasy|Horror',
 'genre_Fantasy|Horror|Mystery',
 'genre_Fantasy|Horror|Mystery|Romance',
 'genre_Fantasy|Horror|Mystery|Thriller',
 'genre_Fantasy|Horror|Romance|Thriller',
 'genre_Fantasy|Horror|Sci-Fi',
 'genre_Fantasy|Horror|Thriller',
 'genre_Fantasy|Mystery|Romance|Sci-Fi|Thriller',
 'genre_Fantasy|Mystery|Thriller',
 'genre_Fantasy|Romance',
 'genre_Film-Noir|Mystery|Romance|Thriller',
 'genre_Horror',
 'genre_Horror|Musical|Sci-Fi',
 'genre_Horror|Mystery',
 'genre_Horror|Mystery|Sci-Fi',
 'genre_Horror|Mystery|Sci-Fi|Thriller',
 'genre_Horror|Mystery|Thriller',
 'genre_Horror|Romance|Thriller',
 'genre_Horror|Sci-Fi',
 'genre_Horror|Sci-Fi|Thriller',
 'genre_Horror|Thriller',
 'genre_Music',
 'genre_Musical',
 'genre_Musical|Romance',
 'genre_Mystery|Romance|Sci-Fi|Thriller',
 'genre_Mystery|Romance|Thriller',
 'genre_Mystery|Sci-Fi|Thriller',
 'genre_Mystery|Thriller',
 'genre_Mystery|Western',
 'genre_Romance',
 'genre_Romance|Sci-Fi|Thriller',
 'genre_Sci-Fi',
 'genre_Sci-Fi|Thriller',
 'genre_Thriller',
 'genre_Thriller|War',
 'genre_Thriller|Western',
 'genre_Western']
Click to add a cell.
    Convert the budget object values to numeric.
    Observe the and print categorical variable counts for Genres, Director, Primary Actor, Secondary Actor, Third Supporting Actor, and Movies Produced by Country.
    """
    model = "gpt-3.5-turbo-0125"
    return get_resp_oai(input_text, model)

response3 = data_transformations()

# %%
display(Markdown("<div style='color: #34568B;'>\n\n" + response3))
# Out:
# <div style='color: #34568B;'>
#
# ---
#
# ```python
# import pandas as pd
#
# # Convert budget object values to numeric
# merged_data['budget'] = pd.to_numeric(merged_data['budget'], errors='coerce')
#
# # Observe and print categorical variable counts for Genres
# genre_cols = [col for col in merged_data.columns if col.startswith('genre_')]
# genre_counts = merged_data[genre_cols].sum()
# print(genre_counts)
#
# # Observe and print categorical variable counts for Director
# director_counts = merged_data['director_name'].value_counts()
# print(director_counts)
#
# # Observe and print categorical variable counts for Primary Actor
# actor_1_counts = merged_data['actor_1_name'].value_counts()
# print(actor_1_counts)
#
# # Observe and print categorical variable counts for Secondary Actor
# actor_2_counts = merged_data['actor_2_name'].value_counts()
# print(actor_2_counts)
#
# # Observe and print categorical variable counts for Third Supporting Actor
# ...

# %%
response3
# Out:
# "---\n\n```python\nimport pandas as pd\n\n# Convert budget object values to numeric\nmerged_data['budget'] = pd.to_numeric(merged_data['budget'], errors='coerce')\n\n# Observe and print categorical variable counts for Genres\ngenre_cols = [col for col in merged_data.columns if col.startswith('genre_')]\ngenre_counts = merged_data[genre_cols].sum()\nprint(genre_counts)\n\n# Observe and print categorical variable counts for Director\ndirector_counts = merged_data['director_name'].value_counts()\nprint(director_counts)\n\n# Observe and print categorical variable counts for Primary Actor\nactor_1_counts = merged_data['actor_1_name'].value_counts()\nprint(actor_1_counts)\n\n# Observe and print categorical variable counts for Secondary Actor\nactor_2_counts = merged_data['actor_2_name'].value_counts()\nprint(actor_2_counts)\n\n# Observe and print categorical variable counts for Third Supporting Actor\nactor_3_counts = merged_data['actor_3_name'].value_counts()\nprint(actor_3_counts)\n\n# O
# ...

# %%
exec(response3[len("---\n\n```python\n"):len(response3)-len("```\n\n---")])
# Out:
# genre_Action                                                     6
# genre_Action|Adventure                                          10
# genre_Action|Adventure|Animation|Comedy|Crime|Family|Fantasy     1
# genre_Action|Adventure|Animation|Comedy|Drama|Family|Sci-Fi      2
# genre_Action|Adventure|Animation|Comedy|Family                   5
#                                                                 ..
# genre_Sci-Fi|Thriller                                           10
# genre_Thriller                                                  11
# genre_Thriller|War                                               1
# genre_Thriller|Western                                           1
# genre_Western                                                    5
# Length: 825, dtype: int64
# Steven Spielberg    26
# Woody Allen         21
# Clint Eastwood      20
# Martin Scorsese     19
# Ridley Scott        17
#                     ..
# Robert Townsend      1
# Jamaa Fanaka         1
# ...
